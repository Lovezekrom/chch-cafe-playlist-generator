# %% [markdown]
# Wrangle the data sources with "online reports for Beaches of COVID-19 Restrictions".

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
event <- read_csv("105 by Dist_data.csv")
event
# Out:
# Rows: 37 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): District
# dbl (2): Alert_Level, Number_of_Reports
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    District                       Alert_Level Number_of_Reports
# 1  Southern                       2            111
# 2  Canterbury                     2            293
# 3  Tasman                         2             63
# 4  Wellington                     2            304
# 5  Central                        2            150
# 6  Eastern                        2             84
# 7  Bay Of Plenty                  2            157
# 8  Waikato                        2            135
# 9  Counties/Manukau               2            192
# 10 Auckland City                  2            409
# ...

# %%
event %>% rename(
    City = District,
    Level = Alert_Level,
    Reports = Number_of_Reports
)
# Out:
#    City                           Level Reports
# 1  Southern                       2      111
# 2  Canterbury                     2      293
# 3  Tasman                         2       63
# 4  Wellington                     2      304
# 5  Central                        2      150
# 6  Eastern                        2       84
# 7  Bay Of Plenty                  2      157
# 8  Waikato                        2      135
# 9  Counties/Manukau               2      192
# 10 Auckland City                  2      409
# 11 Waitemata                      2      251
# 12 Northland                      2       63
# 13 Southern                       3      512
# 14 Canterbury                     3     1074
# 15 Tasman                         3      289
# 16 Wellington                     3      906
# 17 Central                        3      546
# 18 Eastern                        3      326
# 19 Bay Of Plenty                  3      674
# 20 Waikato                        3      652
# ...

# %%
chch_event <- event %>% 
    filter(District == "Canterbury")
chch_event

level4 <- event %>% 
    filter(Alert_Level == 4)
level4
# Out:
#   District   Alert_Level Number_of_Reports
# 1 Canterbury 2            293
# 2 Canterbury 3           1074
# 3 Canterbury 4           6616
#    District                       Alert_Level Number_of_Reports
# 1  Outside New Zealand (District) 4             44
# 2  Southern                       4           3577
# 3  Canterbury                     4           6616
# 4  Tasman                         4           2164
# 5  Wellington                     4           5640
# 6  Central                        4           4166
# 7  Eastern                        4           2231
# 8  Bay Of Plenty                  4           4752
# 9  Waikato                        4           4560
# 10 Counties/Manukau               4           5399
# 11 Auckland City                  4           5877
# 12 Waitemata                      4           6345
# 13 Northland                      4           2116

# %% [markdown]
# As we can see, Canterbury become more and more dangours as the Alert level grows.
# At the level4, the report event is 22 times bigger than level2.
# Canterbury has the highest 105 reports, it also represt Canterbury is the most dangours during the lockdown.
